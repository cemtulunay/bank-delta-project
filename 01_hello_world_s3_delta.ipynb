# %%
print("shuffle partitions:", spark.conf.get("spark.sql.shuffle.partitions"))
print("default parallelism:", spark.conf.get("spark.default.parallelism"))

df = spark.range(0, 1000000)
print("Initial partitions:", df.rdd.getNumPartitions())
# print("Initial partitions:", df.rdd().getNumPartitions())

df = df.repartition(32)
print("Repartitioned partitions:", df.rdd.getNumPartitions())

# %%
# %sql SHOW CATALOGS;

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS workspace_bank.raw;
CREATE SCHEMA IF NOT EXISTS workspace_bank.bronze;
CREATE SCHEMA IF NOT EXISTS workspace_bank.silver;
CREATE SCHEMA IF NOT EXISTS workspace_bank.gold;

# %%
# Do a simple transformation + write as Delta to S3
df2 = df.withColumn("is_even", (F.col("id") % 2 == 0).cast("boolean"))

# df2.write.format("delta").mode("overwrite").save(raw_path)1
df2.write.format("delta").mode("overwrite").saveAsTable("workspace_bank.raw.hello_world")

# %%
df = spark.table("workspace_bank.raw.hello_world")

# %%
# %sql
INSERT INTO workspace_bank.raw.hello_world VALUES ();

# %%
# %sql
INSERT INTO workspace_bank.raw.hello_world (id, is_even)
VALUES
  (100000001, false),
  (100000002, true),
  (100000003, false),
  (100000004, true);

# %%
# %sql DESCRIBE HISTORY workspace_bank.raw.hello_world

# %%
# %sql DESCRIBE TABLE EXTENDED workspace_bank.raw.hello_world
